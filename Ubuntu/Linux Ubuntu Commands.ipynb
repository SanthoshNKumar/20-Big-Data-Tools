# %%
# Open Terminal
Ctrl + Alt + T

# Close Terminal
Ctrl + Shift + w

santhoshNKumar@Ubuntu:~$ sudo poweroff

santhoshNKumar@Ubuntu:~$ sudo reboot

santhoshNKumar@Ubuntu:~/Desktop$ cd \

santhoshNKumar@Ubuntu:~$ pwd

santhoshNKumar@Ubuntu:~$ mkdir /tmp/tutorial

santhoshNKumar@Ubuntu:~$ mkdir dir1 dir2 dir3

# Folder inside folder
santhoshNKumar@Ubuntu:~$ mkdir -p dir4/dir5/dir6

# See the content in the file
santhoshNKumar@Ubuntu:~$ cat output.txt

santhoshNKumar@Ubuntu:~$ clear

# Go to the path
santhoshNKumar@Ubuntu:~$ cd /tmp

# Lists the current directory
santhoshNKumar@Ubuntu:~$ ls

santhoshNKumar@Ubuntu:~$ dir

Ctrl^C (Go to root node)

# Display line of text/string that are passed as an argument 
santhoshNKumar@Ubuntu:~$ echo 'welcome to ubuntu'

# Create new Text File
santhoshNKumar@Ubuntu:~$ nano 1.txt

santhoshNKumar@Ubuntu:~$ cp /home/santhoshNKumar/1.txt /home/santhoshNKumar/Desktop/

# restart the service : xrdp 
santhoshNKumar@Ubuntu:~$ sudo service xrdp restart

# login as user as hdoop
santhoshNKumar@Ubuntu:~$ su - hdoop

# Download the file
santhoshNKumar@Ubuntu:$ wget https://dl.google.com/linux/direct/google-chrome-stable_current_amd64.deb

# get defaukt package Manager
santhoshNKumar@Ubuntu:/tmp$ sudo dpkg -i google-chrome-stable_current_amd64.deb

# Install the software
santhoshNKumar@Ubuntu:/tmp$ sudo apt-get -f install

santhoshNKumar@Ubuntu:/$ sudo apt update

santhoshNKumar@Ubuntu:/$ sudo apt install python3.8

santhoshNKumar@Ubuntu:/$ python3 --version

santhoshNKumar@Ubuntu:/$ java -version; javac -version

# Extract the ziped file
santhoshNKumar@Ubuntu:/$ tar xzf hadoop-3.2.2.tar.gz

# Add new user
santhoshNKumar@Ubuntu:/$ sudo adduser hdoop sudo

# Rename the file
hdoop@Ubuntu:~$ mv spark-3.2.0-bin-hadoop3.2 spark

# Check the spark Home path
hdoop@Ubuntu:~$ echo $SPARK_HOME

# Remove or delete the file
hdoop@Ubuntu:~$ rm spark-3.2.0-bin-hadoop3.2
