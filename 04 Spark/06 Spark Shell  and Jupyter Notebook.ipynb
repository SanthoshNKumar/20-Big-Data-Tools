# %% [markdown]
# ### Spark Shell

# %%
'''
Write pyspark Application two modes
    1. Interactive  -- Pysaprk Shell
    2. Batch Application -- (Jupyter notebook, Pycharm, etc...)

# %%
'''
Pysaprk Shell
    - Spark comes with an interactive python shell.
    - The PySpark shell is responsible for linking the python API to the spark core and initializing the spark context.
    - Pysaprk shell provides default SparkContext as variable named 'sc'
    - Pysaprk shell provides default SparkSessipon as variable named 'spark'

# %%
'''
bin/PySpark command will launch the Python interpreter to run PySpark application

# %% [markdown]
# ![17.png](attachment:17.png)

# %%
'''
PySpark can be launched directly from the command line for interactive use.

# %% [markdown]
# ![17.png](attachment:17.png)

# %%
'''
Command : pyspark --master local[4]
    
    meaning the spark context of this spark shell acts as a master on local node with 4 threads.

# %% [markdown]
# ![20.png](attachment:20.png)

# %%
'''
You can access the web UI 
    - http://localhost:4040
    
Spark context Web UI would be available at http://localhost:4040 [The default port is 4040]. 
Open a browser and hit the url http://localhost:4040.

# %% [markdown]
# ![21.JPG](attachment:21.JPG)

# %%
'''
Sample Program on Pyspark shell

# %% [markdown]
# ![18.JPG](attachment:18.JPG)

# %%
'''
Exit Pyspark shell

# %% [markdown]
# ![19.png](attachment:19.png)

# %%
'''
Example 2 : Word Count

# %% [markdown]
# ![23.png](attachment:23.png)

# %% [markdown]
# ![22.JPG](attachment:22.JPG)

# %% [markdown]
# ### Access Spark from Jupyter notebook

# %%
# pip install findspark

# %%
# Testing pyspark Intallation
import findspark
findspark.init('C:\Spark')
findspark.find()

import pyspark
findspark.find()
# Out:
# 'C:\\Spark'

# %%
# Initialize Spark Context

from pyspark import SparkContext
from pyspark.sql import SparkSession

# Defaine Spark Configuration
conf = pyspark.SparkConf().setAppName("SparkApp").setMaster('local')

# Create SparkSession
sc = pyspark.SparkContext(conf=conf)

spark = SparkSession(sc)

# %%
# Example
val = sc.parallelize([1,2,3,4,5])
val.map(lambda x: x*x*x).collect()

#Output : [1, 8, 27, 64, 125]

# %%
#Stop the sesssion
sc.stop()

# %%
import pyspark
from pyspark.sql import SparkSession

spark = SparkSession.builder.master("local[1]").appName('SparkByExamples.com').getOrCreate()

spark
# Out:
# ---------------------------------------------------------------------------
# Py4JError                                 Traceback (most recent call last)
# <ipython-input-4-27e4b497b36f> in <module>
#       2 from pyspark.sql import SparkSession
#       3
# ----> 4 spark = SparkSession.builder.master("local[1]").appName('SparkByExamples.com').getOrCreate()
#       5
#       6 spark
#
# c:\users\bmi_cims\appdata\local\programs\python\python36\lib\site-packages\pyspark\sql\session.py in getOrCreate(self)
#     226                             sparkConf.set(key, value)
#     227                         # This SparkContext may be an existing one.
# --> 228                         sc = SparkContext.getOrCreate(sparkConf)
#     229                     # Do not update `SparkConf` for existing `SparkContext`, as it's shared
#     230                     # by all sessions.
#
# ...
