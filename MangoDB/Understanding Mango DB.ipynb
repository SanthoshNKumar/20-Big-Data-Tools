# %%
'''
What is mango DB?
    MandoDb is a cross platform document-oriented database program classified as a NoSQL database program.
    MangoDB uses JSON-like documents with schema.

Important Commands

#1 : Create Database
use DATABASE_NAME

#2 : Check currely used database
db

#3 : Show all the data bases 
show dbs

#4 : Insert document into collection
db.movie.inset({"name":"tutorial point"})

#5 : Drop or Delete Database
db.dropDatabase()

#6 : Create Collection(Table)
  - createCollection() method without options
    db.createCollection("mycollection")
  - Create collection by using the command show collections.
  - db.createCollection("mycol", { capped : true, autoIndexId : true, size :6142800, max : 10000 } )

#7 : Show collection(Tables)
show collections

#8 : Drop or Delete Collection
db.COLLECTION_NAME.drop()

#9 : Remove document from the collection
db.COLLECTION_NAMe.remove(parameter1,parameter2)
This Takes two parameters
	deletion criteria - (Optional) deletion criteria according to documents will be removed.
	justOne - (Optional) if set to true or 1, then remove only one document.

#10 : Remove Only One
If there are multiple records and you want to delete only the first record, then set justOne parameter in remove() method.

#11 : Remove All Documents
If you don't specify deletion criteria, then MongoDB will delete whole documents from the collection.

Projection : Projects means selecting only the necessary data rather than selecting whole of the data of a document.
Example if a document has 5 fields and you need to show only 3 then select only 3 fields from them

#12:Display number of documents in the collection
db.COLLECTION_NAME.find().limit(NUMBER)
Note : If you don't specify the number argument in limit() method then it will display all documents from the collection.

#13 : db.COLLECTION_NAME.find().limit(NUMBER).skip(NUMBER)

#14 : To sort documents in MangoDB, you need to use sort() method. 
This method accepts a document containing a list of fields along with sorting order.
sorting order 1 and -1 are used
1 for ascending and -1 for descending order

db.COLLECTION_NAME.find().sort({KEY:1})
db.mycol.find({},{"title":1,_id:0}).sort({"title":-1})

#15:
